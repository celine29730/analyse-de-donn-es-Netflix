# %%
import pandas as pd

# %% [markdown]
# Lien vers le MCD
#
# https://lucid.app/lucidchart/37cb0f6a-4469-470c-9b4d-7508ee0ac378/edit?beaconFlowId=429B1DB632CC93D3&page=0_0#?folder_id=home&browser=icon

# %%
# le dataset, on le réduit pour supprimer les valeurs nulles
data_netflix = pd.read_csv('netflix_titles.csv')
data_reduit = data_netflix.dropna()
data_reduit
# Out:
#        show_id     type                                    title  \
# 0     81145628    Movie  Norm of the North: King Sized Adventure
# 4     80125979    Movie                             #realityhigh
# 6     70304989    Movie                                 Automata
# 7     80164077    Movie       Fabrizio Copano: Solo pienso en mi
# 9     70304990    Movie                              Good People
# ...        ...      ...                                      ...
# 6142  80063224  TV Show            The Great British Baking Show
# 6158  80164216  TV Show  Miraculous: Tales of Ladybug & Cat Noir
# 6167  80115328  TV Show                             Sacred Games
# 6182  80176842  TV Show                         Men on a Mission
# 6213  80126599  TV Show                         Leyla and Mecnun
#
#                                   director  \
# 0                 Richard Finn, Tim Maltby
# 4                         Fernando Lebrija
# 6                              Gabe Ibáñez
# 7          Rodrigo Toro, Francisco Schultz
# 9                        Henrik Ruben Genz
# ...                                    ...
# 6142                       Andy Devonshire
# 6158                         Thomas Astruc
# 6167  Vikramaditya Motwane, Anurag Kashyap
# 6182                            Jung-ah Im
# 6213                             Onur Ünlü
#
#                                                    cast  \
# 0     Alan Marriott, Andrew Toth, Brian Dobson, Cole...
# 4     Nesta Cooper, Kate Walsh, John Michael Higgins...
# 6     Antonio Banderas, Dylan McDermott, Melanie Gri...
# 7                                       Fabrizio Copano
# 9     James Franco, Kate Hudson, Tom Wilkinson, Omar...
# ...                                                 ...
# 6142  Mel Giedroyc, Sue Perkins, Mary Berry, Paul Ho...
# 6158  Cristina Vee, Bryce Papenbrook, Keith Silverst...
# 6167  Saif Ali Khan, Nawazuddin Siddiqui, Radhika Ap...
# 6182  Ho-dong Kang, Soo-geun Lee, Sang-min Lee, Youn...
# 6213  Ali Atay, Melis Birkan, Serkan Keskin, Ahmet M...
#
#                                              country         date_added  \
# 0           United States, India, South Korea, China  September 9, 2019
# 4                                      United States  September 8, 2017
# 6             Bulgaria, United States, Spain, Canada  September 8, 2017
# 7                                              Chile  September 8, 2017
# 9     United States, United Kingdom, Denmark, Sweden  September 8, 2017
# ...                                              ...                ...
# 6142                                  United Kingdom    August 30, 2019
# 6158                      France, South Korea, Japan     August 2, 2019
# 6167                            India, United States    August 15, 2019
# 6182                                     South Korea      April 9, 2019
# 6213                                          Turkey     April 15, 2017
#
#       release_year rating   duration  \
# 0             2019  TV-PG     90 min
# 4             2017  TV-14     99 min
# 6             2014      R    110 min
# 7             2017  TV-MA     60 min
# 9             2014      R     90 min
# ...            ...    ...        ...
# 6142          2019  TV-PG  7 Seasons
# 6158          2018  TV-Y7  4 Seasons
# 6167          2019  TV-MA  2 Seasons
# 6182          2019  TV-14  4 Seasons
# 6213          2014  TV-PG  3 Seasons
#
#                                               listed_in  \
# 0                    Children & Family Movies, Comedies
# 4                                              Comedies
# 6     International Movies, Sci-Fi & Fantasy, Thrillers
# 7                                       Stand-Up Comedy
# 9                         Action & Adventure, Thrillers
# ...                                                 ...
# 6142                       British TV Shows, Reality TV
# 6158                    Kids' TV, TV Action & Adventure
# 6167  Crime TV Shows, International TV Shows, TV Dramas
# 6182  International TV Shows, Korean TV Shows, Stand...
# 6213  International TV Shows, Romantic TV Shows, TV ...
#
#                                             description
# 0     Before planning an awesome wedding for his gra...
# 4     When nerdy high schooler Dani finally attracts...
# 6     In a dystopian future, an insurance adjuster f...
# 7     Fabrizio Copano takes audience participation t...
# 9     A struggling couple can't believe their luck w...
# ...                                                 ...
# 6142  A talented batch of amateur bakers face off in...
# 6158  When Paris is in peril, Marinette becomes Lady...
# 6167  A link in their pasts leads an honest cop to a...
# 6182  Male celebs play make-believe as high schooler...
# 6213  Destiny brings Mecnun and Leyla together as ne...
#
# [3774 rows x 12 columns]

# %%
#creation du data-set réduit en csv
#data_reduit.to_csv('data_reduit2.csv')

# %%
#fragmentation du contenus des cases pour avoir un jeu de donné exploitable
director = list(data_reduit["director"].values)
director_set = set()


for i in range(len(director)):
    liste = director[i]
    dir_ = liste.split(", ")
    for y in dir_:
        director_set.add(y)

director_set
# Out:
# {'Brandon Camp',
#  'Marti Noxon',
#  'Jason Bourque',
#  'Norberto López Amado',
#  'Dibakar Banerjee',
#  'Sudhanshu Saria',
#  'P.K. Baaburaaj',
#  'Federico Veiroj',
#  'Damián Romay',
#  'Simon Curtis',
#  'Derek Peck',
#  'Balu Mahendra',
#  'Aaron Moorhead',
#  'Amr Arafa',
#  'Adrian Murray',
#  'Simon Savelyev',
#  'Anand Tiwari',
#  'Ibai Abad',
#  'Shawn Arranha',
#  'Anurag Singh',
#  'Don Mancini',
#  'Rachel Lears',
#  'Jared Cohn',
#  'Laura Alvea',
#  'Mark Henn',
#  'Brent Maddock',
#  'Datta Mohan Bhandare',
#  'Nikhil Advani',
#  'Ben Ryder',
#  'Lionel C. Martin',
#  'Isabel Coixet',
#  'Yasushi Muraki',
#  'Baz Luhrmann',
#  'Dan Gilroy',
#  'Álvaro Brechner',
#  'Park In-je',
#  'Cathy Garcia-Molina',
#  'Tanveer Khan',
#  'Toshiya Shinohara',
#  'Rusty Cundieff',
#  'Jeff Gill',
#  'Amir Mohiuddin',
#  'Kieran Darcy-Smith',
#  'Will Yapp',
#  'Mario Miscione',
#  'Danny J. Boyle',
#  'Lotje Sodderland',
#  'Ola Flyum',
#  'Frank Ariza',
#  'Randall Lobb',
#  'David Silberg',
#  'James Barr',
#  'Gaurav Bavdankar',
#  'Seth Henrikson',
#  'Scott Aukerman',
#  'Tony Stone',
#  'Adam Dubin',
#  'Iwao Takamoto',
#  'Radhika Rao',
#  'Dan Kwan',
#  'Onur Bilgetay',
#  'Stuart Orme',
#  'Terry Jones',
#  'Jorge Michel Grau',
#  'Ladislas Chollat',
#  'Gary Young',
#  'Tim Van Someren',
#  'Miguel Ángel Vivas',
#  'Samir Karnik',
#  'Ishaya Bako',
#  'Curro Velázquez',
#  'Matthew Vaughn',
#  'Tugçe Soysop',
#  'John Michael McDonagh',
#  'Eric Bross',
#  'Saratswadee Wongsomphet',
#  'Ken Burns',
#  'Tim Hill',
#  'Miguel Cohan',
#  'Erol Özlevi',
#  'Corbin Bernsen',
#  'Aadish Keluskar',
#  'Michel Tikhomiroff',
#  'Ivan Ayr',
#  'Dave Dorsey',
#  'Jun Falkenstein',
#  'Arthur Muhammad',
#  'Frank Paur',
#  'Shyam Benegal',
#  'Eric Laneuville',
#  'Theodore Boborol',
#  'Jon Olb',
#  'Zoe Lister-Jones',
#  'Yuen Woo-ping',
#  'Sonny Mallhi',
#  'Afonso Poyart',
#  'Carlos Therón',
#  'Lee Yoon-jung',
#  'Daniel Calparsoro',
#  'Alex Smith',
#  'Peter Yost',
#  'Pia Sukanya',
#  'Max Martini',
#  'Dan Villegas',
#  'Michael A. Nickles',
#  'Jérémy Clapin',
#  'Rebecca Addelman',
#  'Ishi Rudell',
#  'Stephen Herek',
#  'Kabir Khan',
#  'Alex Israel',
#  'Bronwen Hughes',
#  'Mark Tonderai',
#  'Rhiannon Bannenberg',
#  'Diego Cohen',
#  'Jim Gable',
#  'Marie Madinier',
#  'Toshiyuki Kubooka',
#  'Ruel S. Bayani',
#  'Debaloy Dey',
#  'Chris Williams',
#  'Sajid Khan',
#  "Anthony D'Souza",
#  'Girish Joshi',
#  'Jackie van Beek',
#  "Federico D'Alessandro",
#  'Ziga Virc',
#  'Isabelle Nanty',
#  'Gail Willumsen',
#  'Gary Wheeler',
#  'Kobun Shizuno',
#  'Robin Aubert',
#  'Roman Gackowski',
#  'Sunil Soraya',
#  'Mike Gabriel',
#  'Dito Montiel',
#  'Tommy Avallone',
#  'Anant Balani',
#  'Carly Stone',
#  'Atharv Baluja',
#  'Sarah Kruchowski',
#  'Karen Moncrieff',
#  'Navneet Behal',
#  'Kiran Rao',
#  'Alban Teurlai',
#  'Steve Race',
#  'McG',
#  'Ben Young',
#  'Leanne Gater',
#  'Rene Liu',
#  'Michael Pressman',
#  'Nick Davis',
#  'Hannes Stöhr',
#  'Aatmaram Dharne',
#  'Alex Díaz',
#  'Joel Crawford',
#  'Rupert Jones',
#  'Henrik Ruben Genz',
#  'Rian Johnson',
#  'Dharmesh Darshan',
#  'Juan Antin',
#  'Nicholas Winter',
#  'Kyle Rideout',
#  'Jerry G. Angelo',
#  'Michael Barrett',
#  'Johnny Castuciano',
#  'Nicholas McCarthy',
#  'Chia-Liang Liu',
#  'Anthony Palmer',
#  'Andrew Niccol',
#  'Steven Gomez',
#  'Paresh Mokashi',
#  'Birkan Pusa',
#  'N. Chandra',
#  'Stephen Chow',
#  'Pawan Kripalani',
#  'Mati Diop',
#  'Paritosh Painter',
#  'Jonathan Sobol',
#  'Ismail Farouk',
#  'Chandan Arora',
#  'Gabe Ibáñez',
#  'Ricky Gervais',
#  'Joanna Lombardi',
#  'Patrick Leung',
#  'Phil Nibbelink',
#  'Gregory Hoblit',
#  'Michael Feifer',
#  'Juan Zapata',
#  'Lev L. Spiro',
#  'Hiromasa Yonebayashi',
#  'Suseenthiran',
#  'Yibrán Asuad',
#  'Soumitra Ranade',
#  'Kookie V. Gulati',
#  'Tom Forrest',
#  'Carlo Padial',
#  'Philip G. Atwell',
#  'Chris Eigeman',
#  'Indrajit Nattoji',
#  'Christopher Martin',
#  'Douglas McGrath',
#  'Guntur Soeharjanto',
#  'Fernando González Molina',
#  'Seth Barrish',
#  'James Foley',
#  'Jean-Pierre Dardenne',
#  'Svetlana Cvetko',
#  'Rene Bueno',
#  'Michelle Caputo',
#  'Abhinav Shiv Tiwari',
#  'Ayush Raina',
#  'Sara Colangelo',
#  'Tim Johnson',
#  'Heidi Saman',
#  'Wade Allain-Marcus',
#  'John Stewart Muller',
#  'Daniel Lee',
#  'Brian M. Conley',
#  'Nabil Ayouch',
#  'Buta Singh',
#  'Corey Yuen',
#  'Amol Palekar',
#  'Alan J. Pakula',
#  'Hang-Jun Jang',
#  'Ryan Koo',
#  'Will Lowell',
#  'Sandeep Reddy Vanga',
#  'Milla Harrison-Hansley',
#  'Abhay Chopra',
#  'Tianyu Zhao',
#  'Carlos Vermut',
#  'Greg MacGillivray',
#  'Evan Katz',
#  'Santwana Bardoloi',
#  'Yeo Siew Hua',
#  'Hajime Kamegaki',
#  'Archie Borders',
#  'Olivier Assayas',
#  'Wash Westmoreland',
#  'Shadi Ali',
#  'Rajiv Chilaka',
#  'Marcelo Galvão',
#  'Tim Bartley',
#  'Jung Ji-woo',
#  'Michael Buster',
#  'Walter C. Miller',
#  'Abhishek Kapoor',
#  'Mel Stuart',
#  'Shanker Raman',
#  'Soumendra Padhi',
#  'Hashim Nadeem Khan',
#  'Anna Boden',
#  'Swapna Waghmare Joshi',
#  'Makarand Mane',
#  'Errol Morris',
#  'Suman Ghosh',
#  'Jeon Go-woon',
#  'Şenol Sönmez',
#  'Phillip Noyce',
#  'Amar Kaushik',
#  'Ömer Faruk Sorak',
#  'Mamat Khalid',
#  'Lorene Machado',
#  'Amal Neerad',
#  'Ham Tran',
#  'Sergio Barrejón',
#  'Florent Bodin',
#  'Myles Kane',
#  'Peter Spirer',
#  'Karim El Sobky',
#  'Gareth Evans',
#  'Callie Khouri',
#  'Jon Avnet',
#  'Jim Mickle',
#  'Kemi Adetiba',
#  'Rocky Soraya',
#  'Ana Quiroga',
#  'Sriram Raghavan',
#  'Sukhbir Singh',
#  'Anjum Shahzad',
#  'Rebecca Zlotowski',
#  'David Raynr',
#  'Haissam Hussain',
#  'Ozan Açıktan',
#  'Dylan Haegens',
#  'Mario Rouleau',
#  'Ricardo Maldonado',
#  'Timothy Reckart',
#  'Nattawut Poonpiriya',
#  'Ken Loach',
#  'Gauri Shinde',
#  'Greg Young',
#  'Bradley Walsh',
#  'Dominic Sena',
#  'Stanley Kubrick',
#  'Christopher Chambers',
#  'Neil Jordan',
#  'Valli Bindana',
#  'Stephen Belber',
#  'Ben Patterson',
#  'Samit Kakkad',
#  'David E. Talbert',
#  'Hèctor Hernández Vicens',
#  'Shrihari Sathe',
#  'Jennifer Baichwal',
#  'Rita Coburn Whack',
#  'Jimmy Henderson',
#  'Ken Kwapis',
#  'Teddy Lussi-Modeste',
#  'Anubhav Sinha',
#  'Joe Dante',
#  'M. Night Shyamalan',
#  'Aaron Hann',
#  'Mahmoud Karim',
#  'Thomas Astruc',
#  'Sean Olson',
#  'Jay Chandrasekhar',
#  'Tolga Örnek',
#  'Bong Joon Ho',
#  'Bob Odenkirk',
#  'Manika Sharma',
#  'Karthik Subbaraj',
#  'Drew Stone',
#  'Manuel Martín Cuenca',
#  'Yann Gozlan',
#  'Linda Mendoza',
#  'Edward Cotterill',
#  'Larry Latham',
#  'Nahnatchka Khan',
#  'Karey Kirkpatrick',
#  'Greg Mottola',
#  'Gordon Parks',
#  'Logan Kibens',
#  'Jedd Wider',
#  'Ben Shelton',
#  'Kevin MacDonald',
#  'Bobby Roth',
#  'Prasanth Varma',
#  'Jean-Marc Vallée',
#  'Advait Chandan',
#  'Dan Bush',
#  'Tom Holland',
#  'Hirotsugu Kawasaki',
#  'Sigrid Andrea Bernardo',
#  'Sean Menard',
#  'Paul Reubens',
#  'Mahmoud Sabbagh',
#  'Fernando Sariñana',
#  'Roman Coppola',
#  'Sebastian DiNatale',
#  'Sushil Majumdar',
#  'Richard Correll',
#  'Jeff Baena',
#  'Eduardo Mendoza de Echave',
#  'Faozan Rizal',
#  'Jennifer Westcott',
#  'Mike Binder',
#  'Maciej Dejczer',
#  'Chris Sivertson',
#  'Vincent Perez',
#  'Warren P. Sonoda',
#  'Florian Henckel von Donnersmarck',
#  'Luke Snellin',
#  'Mark Murphy',
#  'Michael Cumming',
#  'Tim Rouhana',
#  'Manbhavan Singh',
#  'Troy Miller',
#  'Lucien Jean-Baptiste',
#  'Pawan K Shrivastava',
#  'Attila Till',
#  'Anthony Chan',
#  'Stanisław Różewicz',
#  'Michael Mason',
#  'Abu Bakr Shawky',
#  'Vijay Kumar',
#  'Manussa Vorasingha',
#  'Kundan Shah',
#  'Jeff Wadlow',
#  'Martin Zandvliet',
#  'Santosh Manjrekar',
#  'Fabrizio Copano',
#  'Kevin Layne',
#  'Julius R. Nasso',
#  'Holger Tappe',
#  'Charlotte Zwerin',
#  'Pang Ho-cheung',
#  'Osman Ali',
#  'Michael James Regan',
#  'Tig Notaro',
#  'Mandla Dube',
#  'John Upchurch',
#  'Kristin Hanggi',
#  'Nisheeta Keni',
#  'Erik Matti',
#  'Griffin Dunne',
#  'Steve Ball',
#  'Mickey Liddell',
#  'Çagan Irmak',
#  'Adrian Teh',
#  'Amardeep Singh Gill',
#  'Drue Metz',
#  'Tony Kaye',
#  'Simon Wincer',
#  'Manish Tiwary',
#  'Kurt Voelker',
#  'Olivier Marchal',
#  'Daniel McCabe',
#  'Robert Vince',
#  'Rob Burnett',
#  'Suzanne Coote',
#  'Leena Yadav',
#  'Eric Summer',
#  'Rodrigo Triana',
#  'Terry Loane',
#  'Kim Joo-hyung',
#  'Jared Hess',
#  'Toa Fraser',
#  'Joe Berlinger',
#  'Cary Murnion',
#  'Matt Piedmont',
#  'Edgar Wright',
#  'Brad Bird',
#  'Christopher Nolan',
#  'Ahsan Rahim',
#  'Sinan Akkuş',
#  'Stacy Title',
#  'Gerardo Olivares',
#  'David Palmer',
#  'Maya Forbes',
#  'Peter Ho',
#  'Hani Hamdi',
#  'Robert Markowitz',
#  'Jocelyn Moorhouse',
#  'J.M. Berrios',
#  'Justin G. Dyck',
#  'John Lyde',
#  'Mike Clattenburg',
#  'Ari Sandel',
#  'Smeep Kang',
#  'Mikhail Red',
#  'Yoav Paz',
#  'Tom Shadyac',
#  'Daniel Monzón',
#  'Diego Corsini',
#  'Will Lovelace',
#  'Arjun Jandyala',
#  'Tony Zierra',
#  'Antonio Serrano',
#  'Andrew Loo',
#  'Mohamed Diab',
#  'Floyd Russ',
#  'Daisuke Nishio',
#  'Emilio Martínez Lázaro',
#  'Faraz Haider',
#  'Mandeep Kumar',
#  'Ahishor Solomon',
#  'Ossama Abu El Atta',
#  'Andrew Sullivan',
#  'R. Ellis Frazier',
#  'Alex Law',
#  'Roger Young',
#  'Debra Granik',
#  'Ridley Scott',
#  'Francesco Imperato',
#  'Robb Wells',
#  'Joyce Bernal',
#  'Natalie Portman',
#  'John Hughes',
#  'Darren Lynn Bousman',
#  'Gordon Anderson',
#  'Stacia Crawford',
#  'Hiroshi Aoyama',
#  'Apoorva Lakhia',
#  'Kyle Newman',
#  'Liv Ullmann',
#  'Ben Pluimer',
#  'Rod Blackhurst',
#  'Brian Klein',
#  'Rahat Rahman',
#  'Ed Lilly',
#  "Bill D'Elia",
#  'Michael Paul Stephenson',
#  'Onir',
#  'Jesse Gustafson',
#  'Sean McNamara',
#  'Janusz Majewski',
#  'Kim Nguyen',
#  'Myriam Aziza',
#  'Pierre Coré',
#  'Corey Grant',
#  'James L. Brooks',
#  'Kery James',
#  'Ari Folman',
#  'Ann Deborah Fishman',
#  'Eeshwar Nivas',
#  'Davis Guggenheim',
#  'Jesse Allain-Marcus',
#  'Joel Coen',
#  'T.J. Martin',
#  'Filip Renc',
#  'Demetri Martin',
#  'Castille Landon',
#  'Syed Saleh Ahmed Sobhan',
#  'Manjeet Maan',
#  'Rob Marshall',
#  'Tanuj Chopra',
#  'Craig Elrod',
#  'Tarek Al Eryan',
#  'Scott McAboy',
#  'Nathan Greno',
#  'Deep Joshi',
#  'Robiul Alam Robi',
#  'Aanand Rai',
#  'Andrew Stanton',
#  'John Milius',
#  'Pedro Coutinho',
#  'Richard Miron',
#  'Rudy Soedjarwo',
#  'Nuel Naval',
#  'Alistair Legrand',
#  'Rakshith Thirthahalli',
#  'Atanu Mukherjee',
#  'Ali Samadi Ahadi',
#  'Paul W.S. Anderson',
#  'Onur Ünlü',
#  'L. Frazier',
#  'Paul Serafini',
#  'Courtney Hunt',
#  'Shadab Khan',
#  'Stig Bergqvist',
#  'Nana Ekvtimishvili',
#  'Trent Haaga',
#  'Tilak Shetty',
#  'Subhash Ghai',
#  'Cristina Jacob',
#  'Vicente Villanueva',
#  'Scott Zabielski',
#  'Gus Van Sant',
#  'Alejandro Montiel',
#  'Sartaj Singh Pannu',
#  'Sam Patton',
#  'Koichi Sakamoto',
#  'Reginald Hudlin',
#  'Stephen Gyllenhaal',
#  'Chiwetel Ejiofor',
#  'Taika Waititi',
#  'Ding Sheng',
#  'Oz Rodriguez',
#  'John Lee',
#  'Shaina Allen',
#  'Charles Martin Smith',
#  'Pradip Kurbah',
#  'Alex Brewer',
#  'Keanu Reeves',
#  'David Morris',
#  'Amitava Bhattacharya',
#  'Louie Psihoyos',
#  'Sundar C.',
#  'Alex Winter',
#  'Anand Tucker',
#  'Emily Hagins',
#  'Anthony Pierce',
#  'Benjamin Dickinson',
#  'Teo Konuralp',
#  'Shirish Kunder',
#  'Lenin Bharathi',
#  'Trevor Ryan',
#  'Jonathan Taylor',
#  'Sarjun',
#  'Mohamed Mostafa',
#  'David Gelb',
#  'David Fairhead',
#  'Aziz Mirza',
#  'M.S. Prem Nath',
#  'Kevin Deters',
#  'Max McGill',
#  'Thomas Stuber',
#  'Yen Cheng-kuo',
#  'Jason Reitman',
#  'Gordon Chan',
#  'Aitor Arregi',
#  'Jehane Noujaim',
#  'William Bindley',
#  'S.S. Rajamouli',
#  'Anthony Byrne',
#  'Derek Yee',
#  'Franck Ekinci',
#  'Sanjay Leela Bhansali',
#  'Roman Atwood',
#  'Benny Fredman',
#  'Robert Kouba',
#  'Felix Thompson',
#  'Wagner de Assis',
#  'Mark Craig',
#  'Roy Burdine',
#  'Yayo Herrero',
#  'Shawn Levy',
#  'Aziz Ansari',
#  'R. Kannan',
#  'Espen Sandberg',
#  'Paakhi Tyrewala',
#  'Michael Cuesta',
#  'Nathanael Wiseman',
#  'Zakariya',
#  'July Hygreck',
#  'Norman Jewison',
#  'Rana Ranbir',
#  'Steve Hickner',
#  'Dennis Rovira van Boekholt',
#  'Andrea Arnold',
#  'Kelly Fremon Craig',
#  'Stéphane Berla',
#  'Ole Bornedal',
#  'Craig Brewer',
#  'David Chirchirillo',
#  'Michael Petroni',
#  'Tom Hooper',
#  'Ksshitij Chaudhary',
#  'Kevin Kolsch',
#  'Ken Marino',
#  'Fernando Colomo',
#  'Ben Palmer',
#  'Zoya Akhtar',
#  'Benjamin Ree',
#  'Clive Tonge',
#  'Aditya Kripalani',
#  'Alexis Morante',
#  'Khalid Kashogi',
#  'Alain Desrochers',
#  'Tim Story',
#  'Scott Marshall Smith',
#  'Vikram Tanajirao Patil',
#  'Dennis Bartok',
#  'Husam El-Gohari',
#  'James Hawes',
#  'Kaila York',
#  'Joe DeMaio',
#  'Akram Farouk',
#  'Fedor Lyass',
#  'David Pastor',
#  'Kazuya Murata',
#  'G.J. Echternkamp',
#  'Santram Varma',
#  'Óskar Thór Axelsson',
#  'Alfonso Serrano Maturino',
#  'Nikhil Nagesh Bhat',
#  'Shinsuke Sato',
#  'Raúl Campos',
#  'Sridhar Jetty',
#  'Aniruddha Roy Chowdhury',
#  'Robert O. Peters',
#  'David Lam',
#  'Pan Nalin',
#  'Nidhi Sharma',
#  'Sophon Sakdaphisit',
#  'Jon Garaño',
#  'James Dearden',
#  'Shawn Crahan',
#  'Alex Timbers',
#  'Oriol Paulo',
#  'Sam Voutas',
#  'Mike Rossiter',
#  'Ding-Lin Wang',
#  'John G. Avildsen',
#  'Anne Fontaine',
#  'Mahmood Farooqui',
#  'Vijay Milton',
#  'Prabhuraj',
#  'Muh Chen',
#  'Christopher Ray',
#  'Tony Giglio',
#  'Gaurav Narayanan',
#  'Serdar Akar',
#  'Elvira Lind',
#  'Vikram Bhatt',
#  'Mark Osborne',
#  'Chandra Prakash Dwivedi',
#  'Tathagata Banerjee',
#  'Shin Won-ho',
#  'Mark Risley',
#  'Gilbert Chan',
#  'Damien Leone',
#  'Justin Bare',
#  'Fumihiko Sori',
#  'Jason Priestley',
#  'William Lau',
#  'Abhishek Varman',
#  'Aijaz Khan',
#  'Mike Newell',
#  'John R. Leonetti',
#  'Lenny Abrahamson',
#  'Hideki Futamura',
#  'Swapnaneel Jayakar',
#  'Park Joon-hwa',
#  'Kagiso Lediga',
#  'Nuhash Humayun',
#  'Tony Datis',
#  'Maria Pulera',
#  'Amshan Kumar',
#  'Steve Boettcher',
#  'Katherine Fairfax Wright',
#  'Colin Dench',
#  'Michèle Ohayon',
#  'Mario Cambi',
#  'Benjamin Ross',
#  'Lori Kaye',
#  'Oded Raz',
#  'Jordi Llompart',
#  'Abdellatif Kechiche',
#  'C.J. Wallis',
#  'Santosh Sivan',
#  'Mark Waters',
#  'Rick Morales',
#  'Jill Culton',
#  'Nobuyuki Takeuchi',
#  'Prabhu Deva',
#  'Don Michael Paul',
#  'Mark A.Z. Dippé',
#  'Bryan Spicer',
#  'Kazumi Fukushima',
#  'Jayan Vannery',
#  'David Gordon Green',
#  'Anees Bazmee',
#  'Sze Yu Lau',
#  'Joaquín Mazón',
#  'Mario Van Peebles',
#  'Koichi Mashimo',
#  'Michael Kampa',
#  'Will Gluck',
#  'Anthony Russo',
#  'Clay Porter',
#  'Joel Oliansky',
#  'Massy Tadjedin',
#  'Jon Carey',
#  'Chris Bell',
#  'Brian De Palma',
#  'Steve Antin',
#  'Bo Welch',
#  'John Schlesinger',
#  'Abba T. Makama',
#  'Shekhar Kapur',
#  'Amit Saxena',
#  'Buz Wallick',
#  'Max Pugh',
#  'Michael Whitton',
#  'David Carson',
#  'Joe Ksander',
#  'Vijay Kumar Arora',
#  'Rich Ragsdale',
#  'Julien Rambaldi',
#  'Andrew Renzi',
#  'Khaled Marei',
#  'Keiichi Hara',
#  'Martin Scorsese',
#  'Isao Yukisada',
#  'Deniz Gamze Ergüven',
#  'Charlie Siskel',
#  'Lygia Barbosa da Silva',
#  'Iginio Straffi',
#  'Peter Orton',
#  'Jevons Au',
#  'Alejandro Agresti',
#  'Adarsh Eshwarappa',
#  'Vanita Shastry',
#  'Dante Lam',
#  'John Schultz',
#  'Robert C. Ramirez',
#  'Thierry Demaizière',
#  'Lesli Linka Glatter',
#  'Poj Arnon',
#  'Antoine Fuqua',
#  'Craig Anderson',
#  'Jeff Tremaine',
#  'Sam Taplin',
#  'Songyos Sugmakanan',
#  'Brandon Jones',
#  'Jeremy Konner',
#  'Ali Scher',
#  "Tom O'Dell",
#  'Laxman Utekar',
#  'Mar Targarona',
#  'Esteban Vidal',
#  'Louis Leterrier',
#  'Damien O’Connor',
#  'Anthony Minghella',
#  'Caradog W. James',
#  'Dimitri Logothetis',
#  'Shen Chi',
#  'Tobe Hooper',
#  'Kevin Phillips',
#  'Nicolás Silbert',
#  'Mozez Singh',
#  'Michael G. Kehoe',
#  'Artemis Joukowsky',
#  'Khaled El Halafawy',
#  'Makoto Shinkai',
#  'Kunle Afolayan',
#  'Latif Faiziyev',
#  'Toka McBaror',
#  'Gonzalo Bendala',
#  'Anthony Caronna',
#  'Olivia Milch',
#  'Felix van Groeningen',
#  'Roger Allers',
#  'Robert Clouse',
#  'Spike Jonze',
#  'Norton Virgien',
#  'Carlos Marques-Marcet',
#  'Quentin Tarantino',
#  'Daniel Goldhaber',
#  "Meghan O'Hara",
#  'B. Unnikrishnan',
#  'Felix Chong',
#  'Karen J. Lloyd',
#  'Sridhar Rangayan',
#  'Mohammed Hussain',
#  'Andibachtiar Yusuf',
#  'Phuwanit Pholdee',
#  'Ibrahim Bin Mohamed',
#  'Kim Seong-hun',
#  'Lucy van Beek',
#  'Keith Scholey',
#  'Mark Dindal',
#  'Tim Burton',
#  'Vijay Lalwani',
#  'Toshiyuki Tsuru',
#  'Yuen Wo-Ping',
#  'Joe Menendez',
#  'Manish Gupta',
#  'Timothy Woodward Jr.',
#  'George Clooney',
#  'John Papola',
#  'Guy Vasilovich',
#  'Cate Shortland',
#  'Alison MacLean',
#  'Abbas Tyrewala',
#  'Krishna D.K.',
#  'John Kahrs',
#  'Roger Kumble',
#  'Steve Brill',
#  'Nicholas Stoller',
#  'Adam Larson Broder',
#  "André D'Elia",
#  'Andrew Slater',
#  'Paul Raschid',
#  'Woo Min-ho',
#  'Michael Apted',
#  'Emanuel Hoss-Desmarais',
#  'Chun Wong',
#  'Tanuja Chandra',
#  'Rachel Grady',
#  'Elite Zexer',
#  'Jacques Perrin',
#  'John Ford',
#  'Manmohan Desai',
#  'Vinod Kapri',
#  'Gabe Turner',
#  'Sunkanmi Adebayo',
#  'Atlee Kumar',
#  'Alex Richanbach',
#  'Danny Boyle',
#  'Michael Simon',
#  'Mat King',
#  'Noël Wells',
#  'Phil Weinstein',
#  'Luke Kenny',
#  'Azazel Jacobs',
#  'John Mikulak',
#  'Ang Lee',
#  'Michael Tiddes',
#  'John Murlowski',
#  'Riki Lindhome',
#  'Abhishek Saxena',
#  'Nagesh Kukunoor',
#  'Paul Andrew Williams',
#  'Felix Van Groeningen',
#  'Emmett Malloy',
#  'Dorian Fernández-Moris',
#  'Ayaan Mukherji',
#  'C. Fitz',
#  'Gurinder Chadha',
#  'Gabriel Grieco',
#  'Mariano Baez',
#  'Satish Rajwade',
#  'Robyn Butler',
#  'Fazila Allana',
#  'Jordan Brady',
#  'Lee Seung-won',
#  'Teng Huatao',
#  'Salima Koroma',
#  'Jacob Kornbluth',
#  'Sachin Kamlakar Khot',
#  'Jay Baruchel',
#  'Justin McConnell',
#  'Stacie Passon',
#  'Jacob Joice',
#  'Luis Estrada',
#  'Daniel Camenisch',
#  'Ranjit Tiwari',
#  'Yoshiyuki Momose',
#  'Mohamed Hamdy',
#  'Ivan Reitman',
#  'Victor Levin',
#  'You-Jeong Chang',
#  'Lee Chang-dong',
#  'Juani Libonatti',
#  'Alfred Gimeno',
#  'Àlex Pastor',
#  'Mandie Fletcher',
#  'Scott Mosier',
#  'Carlos Algara',
#  'Todd S. Yellin',
#  'Waymon Boone',
#  'Mathieu Auvray',
#  'Audu Paden',
#  'Scott Stewart',
#  'Peter Pardini',
#  'Mohit Suri',
#  'James Mangold',
#  'David Lowery',
#  'Chanon Yingyong',
#  'Satish Kaushik',
#  'Gabe Klinger',
#  'John Huston',
#  'Martin Gorst',
#  'Phil Sgriccia',
#  'RZA',
#  'Kelly Reichardt',
#  'Joe Roth',
#  'Rucha Humnabadkar',
#  'Charles Walters',
#  'Sopon Sukdapisit',
#  'Richard Finn',
#  'Keegan Kuhn',
#  'Nate Adams',
#  'Jelle de Jonge',
#  'Cheang Pou Soi',
#  'Harry Chaskin',
#  'Luk Kim-ching',
#  'Christel Gibson',
#  'Bo Burnham',
#  'Sean Cisterna',
#  'Andy Tennant',
#  'Steve Rash',
#  'Ramón Salazar',
#  'Karyn Kusama',
#  'Sean Hanish',
#  'Geetu Mohandas',
#  'Joseph Mbah',
#  'Juan Carlos Rulfo',
#  'Will Eisenberg',
#  'Joris Ivens',
#  'Alexandre Aja',
#  'Hemant Gaba',
#  'Richard Rich',
#  'White Trash Tyler',
#  'P.T. Kunju Muhammad',
#  'Jason Lai',
#  'Mike Mills',
#  'Kunal Deshmukh',
#  'Gary Shore',
#  'Nancy Meyers',
#  'Jørgen Lerdam',
#  'Andrés Couturier',
#  'Matthew Robinson',
#  'Jonathan Levine',
#  'Soukarya Ghosal',
#  'Martin Campbell',
#  'Saravana Rajendran',
#  'Peter Hewitt',
#  'Chandrakant Kulkarni',
#  'Deepti Naval',
#  'K.C. Bokadia',
#  'Mimi Leder',
#  'Hark Tsui',
#  "Brian O'Malley",
#  'Maximilian Erlenwein',
#  'Aditya Vikram Sengupta',
#  'Benoît Jacquot',
#  'Damien Piscarel',
#  'Mike Disa',
#  'Li Jun',
#  'Yann Arthus-Bertrand',
#  'Anthony Giordano',
#  'Frank Rajah Arase',
#  'Saurav Palodhi',
#  'Atanu Ghosh',
#  'Feroz',
#  'Luis Javier M. Henaine',
#  'Raditya Dika',
#  'Ariel Vromen',
#  'Pepe Bojórquez',
#  'Marc Abraham',
#  'Alexandre Avancini',
#  'Milind Rau',
#  'Karan Shivajirao Chavan',
#  'Magdy Al-Hawwary',
#  'Peter Foott',
#  ...}

# %%
country = list(data_reduit["country"].values)
country_set = set()


for i in range(len(country)):
    liste = country[i]
    dir_ = liste.split(", ")
    for y in dir_:
        country_set.add(y)

country_set
# Out:
# {'Afghanistan',
#  'Albania',
#  'Argentina',
#  'Australia',
#  'Austria',
#  'Bangladesh',
#  'Belgium',
#  'Bermuda',
#  'Brazil',
#  'Bulgaria',
#  'Cambodia',
#  'Canada',
#  'Cayman Islands',
#  'Chile',
#  'China',
#  'Colombia',
#  'Croatia',
#  'Czech Republic',
#  'Denmark',
#  'Dominican Republic',
#  'East Germany',
#  'Ecuador',
#  'Egypt',
#  'Finland',
#  'France',
#  'Georgia',
#  'Germany',
#  'Ghana',
#  'Greece',
#  'Guatemala',
#  'Hong Kong',
#  'Hungary',
#  'Iceland',
#  'India',
#  'Indonesia',
#  'Iran',
#  'Iraq',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Jordan',
#  'Kenya',
#  'Latvia',
#  'Lebanon',
#  'Liechtenstein',
#  'Luxembourg',
#  'Malawi',
#  'Malaysia',
#  'Malta',
#  'Mexico',
#  'Montenegro',
#  'Morocco',
#  'Nepal',
#  'Netherlands',
#  'New Zealand',
#  'Nicaragua',
#  'Nigeria',
#  'Norway',
#  'Pakistan',
#  'Panama',
#  'Paraguay',
#  'Peru',
#  'Philippines',
#  'Poland',
#  'Poland,',
#  'Portugal',
#  'Qatar',
#  'Romania',
#  'Russia',
#  'Saudi Arabia',
#  'Senegal',
#  'Serbia',
#  'Singapore',
#  'Slovakia',
#  'Slovenia',
#  'Somalia',
#  'South Africa',
#  'South Korea',
#  'Soviet Union',
#  'Spain',
#  'Sri Lanka',
#  'Sudan',
#  'Sweden',
#  'Switzerland',
#  'Taiwan',
#  'Thailand',
#  'Turkey',
#  'United Arab Emirates',
#  'United Kingdom',
#  'United States',
#  'Uruguay',
#  'Vatican City',
#  'Venezuela',
#  'Vietnam',
#  'West Germany'}

# %%
actor = list(data_reduit["cast"].values)
actor_set = set()


for i in range(len(actor)):
    liste = actor[i]
    dir_ = liste.split(", ")
    for y in dir_:
        actor_set.add(y)

actor_set
# Out:
# {'Ji-min Han',
#  'Terry Courier',
#  'Heather Locklear',
#  'Jack Roth',
#  'John Lloyd Cruz',
#  'Olimpia Melinte',
#  'JC de Vera',
#  'Mark Benington',
#  'Sarah Viktoria Bjerregaard',
#  'Jack McGee',
#  'Angela Bettis',
#  'Penny Downie',
#  'Bernard Hill',
#  'Marshall Crenshaw',
#  'Aïssa Maïga',
#  'Dawn Olivieri',
#  'Rahul Pethe',
#  'Keppy Ekpenyong',
#  'Pablo Derqui',
#  'Kinna McInroe',
#  'Flynn Curry',
#  'Sudhir Nema',
#  'Ben Bledsoe',
#  'Álvaro Ogalla',
#  'Deborah Grall',
#  'Jason Dolley',
#  'Husni Sheta',
#  'Stephen Gevedon',
#  'José María Pou',
#  'Søren Malling',
#  'Debra Winger',
#  'Cassandra Ciangherotti',
#  'Isaac Hempstead Wright',
#  'Tom Crisp',
#  'Dave schultz',
#  'Leon',
#  'Niklas Bruhn',
#  'Alex Ozerov',
#  'Tony Nikolakopoulos',
#  'Dina Pathak',
#  'Jared Cohn',
#  'Erdal Tosun',
#  'Noelle Balfour',
#  'Elisabeth Catherine Gray',
#  'Devon Terrell',
#  'Sandra Bullock',
#  'Asif Ali',
#  'Elena Mandalis',
#  'Jake Smith',
#  'Melissa Rauch',
#  'Lier Qiu',
#  'Gary Sturm',
#  'Dawn Zulueta',
#  'Ashlyn Drummond',
#  'Yayan Ruhian',
#  'Sam Trammell',
#  'Ray Sahetapy',
#  'Jason Mantzoukas',
#  'Jon Kit Lee',
#  'Francis Onwochei',
#  'James Purefoy',
#  'James Wilks',
#  'Natasa Janjic',
#  'Kett Thantup',
#  'Baz Luhrmann',
#  'Rainer Bock',
#  'Abhishek Saha',
#  'Steven Rishard',
#  'LL Cool J',
#  'Angela Bassett',
#  'Pippa Mackie',
#  'Rene Auberjonois',
#  'Kim Ramirez',
#  'Raquel Presa',
#  'Lilian Dugois',
#  'Graham Verchere',
#  'Lora Martinez-Cunningham',
#  'Biddy Hodson',
#  'Elaine Bilstad',
#  'Vivica A. Fox',
#  'Conor McGregor',
#  'Tamsin Greig',
#  'Claudia Tagbo',
#  'Justin Mark',
#  'Inggrid Widjanarko',
#  'Anthony Hayes',
#  'Dorien Wilson',
#  'Trish Stratus',
#  'Furkan Bayraktar',
#  'Cathy Moriarty',
#  'Anthony Higgins',
#  'Masaki Terasoma',
#  'Julia Davis',
#  'Sanjay Dutt',
#  'Margie McCrae',
#  'Lotje Sodderland',
#  'Mike Dopud',
#  'Doug Erholtz',
#  'Aarushi Sharma',
#  'Sara Loren',
#  'Bhed Sinha',
#  'Laurence Fox',
#  'Sutatta Udomsilp',
#  'Shubham Tukaram',
#  'Raquel Alessi',
#  'Frankie Avalon',
#  'Wil Wheaton',
#  'Scott Aukerman',
#  'Bryce Groark',
#  'Craig Conway',
#  'Leigh Kelly',
#  'Ahmad Thaher',
#  'Clark Middleton',
#  'Silvia Marty',
#  'Teri McMinn',
#  'Rosalina Leigh',
#  'Barry Livingston',
#  'Chris Kattan',
#  'Nadine Lustre',
#  'Patrick Heusinger',
#  'Joseph Benjamin',
#  'Brett Hull',
#  'Irene Escolar',
#  'James Wilby',
#  'Carey Mulligan',
#  'Ayhan Taş',
#  'Tadeusz Schmidt',
#  'Abdullah Bin Haidar',
#  'Jerry Stovin',
#  'Ankush Choudhary',
#  'Monika Panwar',
#  'Zac Zedalis',
#  'Forbes KB',
#  'Max von Sydow',
#  'Justin Clarke Samuel',
#  'Majid Shokor',
#  'Tyler Joseph Campbell',
#  'Sunny Wayne',
#  'Brian Neal Clark',
#  'Arjun Chakrabarty',
#  'Michael Aaron Milligan',
#  'Enchong Dee',
#  'Sota Fukushi',
#  'Lilou Fogli',
#  'Khalil Kain',
#  'Greg Korin',
#  'Eugen Knecht',
#  'Andrew Sachs',
#  'Charles Tyner',
#  'Siobhan McKenna',
#  'Yeong-mun Kwon',
#  'Paris Berelc',
#  'Ra Mi-ran',
#  'Mert Aran',
#  'Sumit Chakravarti',
#  'Brian Atkinson',
#  'Ian Fried',
#  'Dolly Minhas',
#  'Christopher Stapleton',
#  'Lindsey Alena',
#  'Müjde Uzman',
#  'Max Martini',
#  'Dana Gourrier',
#  'Andrew M. Gray',
#  'Mei Nagano',
#  'Michael Thomas',
#  'Stijn Fransen',
#  'Nicolas Bro',
#  'Henry Czerny',
#  'Hussain Dalal',
#  'Jeyan Cherthala',
#  'Norman Lear',
#  'Vince Carter',
#  'Anang Desai',
#  'Tori Kristiansen',
#  'Alejandro Sanz',
#  'Mona Singh',
#  'Joseph Huang',
#  'Christine Allado',
#  'Vanessa Redgrave',
#  'Henry Goodman',
#  'Deepa Sahi',
#  'Roger Ashton-Griffiths',
#  'Thammegowda S.',
#  'Gloria Diaz',
#  'Bobby Schofield',
#  'Yeong-jin Jo',
#  'David Eagleman',
#  'Figs Jackman',
#  'Federico Luppi',
#  'Ingrid Nilson',
#  'Adam Driver',
#  'Matthew Waterson',
#  'Hussan Saad',
#  'Laura Azcurra',
#  'Chacha Huang',
#  'Jackie van Beek',
#  'Aaditi Pohankar',
#  'Aasif Mandvi',
#  'Lou Castel',
#  'Tommy Avallone',
#  'Sathish',
#  'Nico Vink',
#  'Anabela Teixeira',
#  'Umesh Tamang',
#  'Mario Iván Martínez',
#  'James Drury',
#  'James Moses Black',
#  'Savin Phillip',
#  'Vrijesh Hirjee',
#  'Michaela McAllister',
#  "Genelia D'Souza",
#  'Oka Antara',
#  'Tommy Cash',
#  'Caleel Harris',
#  'Mark Addy',
#  'Ethan Hawke',
#  'Pablo Cruz Guerrero',
#  'Leslie Bibb',
#  'Edi Patterson',
#  'Pedro Monteiro',
#  'Suzan Aksoy',
#  'Natassha',
#  'Manya Gupta',
#  'Abhishek Duhan',
#  'Bassel El Kadi',
#  'Awra Briguela',
#  'Leyla Rangel',
#  'Joanne Crawford',
#  'Tinu Verghese',
#  'Denise Boutte',
#  'Edgar Costas',
#  'Sam Louwyck',
#  'Gururaj Manepalli',
#  'Mathew Horne',
#  'Sanath',
#  'Carolina Sarmiento',
#  'Jay',
#  'Menha Zaytoon',
#  'Madhuri Dixit',
#  'Julian Morris',
#  'César Mello',
#  'Sigurdur Jonsson',
#  'Petio Petkov',
#  'David Warner',
#  'Raphael Viana',
#  'Tim Rice',
#  'Portia Doubleday',
#  'Ramesh Deo',
#  'Selvaah',
#  'Chia-Liang Liu',
#  'Emily Rios',
#  'Patrick Doyle',
#  'Neil Young',
#  'Michael Jibson',
#  'Zain Khan Durrani',
#  'John Lithgow',
#  'Martin Sheen',
#  'Neha Khan',
#  'Freddie Spencer',
#  'Jeremy Davies',
#  'Kent Cheng',
#  'Hulk Hogan',
#  'Brian George',
#  'Vijayant Kohli',
#  'Mahreen Kaleka',
#  'Meadow Williams',
#  'Elvis Nolasco',
#  'Vincent Cassel',
#  'Melissa Sagemiller',
#  'Akshay Sachdev',
#  'Christopher Rich',
#  'Lawrence Makoare',
#  'Belinda McClory',
#  'Esteban Ahn',
#  'Greg Grunberg',
#  'Joshua Close',
#  'Jess Weixler',
#  'Emily Spivey',
#  'Ricky Gervais',
#  'Alice Belaïdi',
#  'Natalie Dormer',
#  'Masam Holden',
#  'Archit Deodhar',
#  'Romeo Miller',
#  'Charlie Wernham',
#  'Wood Harris',
#  'Lucy Loken',
#  'Omero Mumba',
#  'Chelsea Peretti',
#  'Carol Kane',
#  'Katie Morgan',
#  'Nora Dunn',
#  'David Duchovny',
#  'Juan Calot',
#  'Malhar Thakar',
#  'Doug Barron',
#  'Wendy Moniz',
#  'Bela B. Felsenheimer',
#  'Todd Field',
#  'Madeline Kahn',
#  'Swara Bhaskar',
#  'Nor Domingo',
#  'Yasser El Tobgy',
#  'Vincent Macaigne',
#  'Fred Willard',
#  'Justin Lieberman',
#  'Rebecca Staab',
#  'Jim Piddock',
#  'Julien Souve',
#  'Ty Simpkins',
#  'Casimere Jollette',
#  'Joel Rush',
#  'Jack Foley',
#  'Xiang Yun',
#  'Shuichi Ikeda',
#  'Si-kyung Sung',
#  'Peter Mullan',
#  'Jemmy Chen',
#  'Haley Lu Richardson',
#  'Jenni Melear',
#  'Suchandra Vaaniya',
#  'Hélène Devos',
#  'Yuriy Kutsenko',
#  'Clint Glenn Hummel',
#  'Shaana Diya',
#  'Lombardo Boyar',
#  'Richard Masur',
#  'Joan Collins',
#  'Jonathan Walker',
#  'Zhang Ziyi',
#  'Emilram Cossío',
#  'Kento Yamazaki',
#  'Aaron Munoz',
#  'Andre Hyland',
#  'Hakou Benosmane',
#  'Omar Chaparro',
#  'Rick Jones',
#  'Jass Bajwa',
#  'Brian Regan',
#  'Kelly B. Jones',
#  'Simon McBurney',
#  'Vidushi Mehra',
#  'Phan Thanh Nhien',
#  'Said Faraj',
#  'Bridget Everett',
#  'Kirk Hammett',
#  'Clint Dyer',
#  'Kevin Jorgeson',
#  'Shunsuke Takeuchi',
#  'Teo Halm',
#  'Elana Krausz',
#  'Divya Rana',
#  'Little Richard',
#  'Chad Smith',
#  'Chris Chalk',
#  'Kimia Hosseini',
#  'Madeline Zima',
#  'Ethan Peck',
#  'Jérôme Niel',
#  'Bruce Dern',
#  'Don Messick',
#  'Noel Gallagher',
#  'André Holland',
#  'Meredith Hagner',
#  'Sam Robards',
#  'Man-seok Oh',
#  'Lim Hyung-kuk',
#  'Alycia Debnam-Carey',
#  'David So',
#  'Archana Padmini',
#  'Jenn McAllister',
#  'William Sadler',
#  'Lisa Amedjout',
#  'Halston Sage',
#  'Aditi Arya',
#  'Helen Mirren',
#  'Jack Lowden',
#  'Bogdan Iancu',
#  'Freddie Highmore',
#  'Dee Wallace',
#  'Bas Rutten',
#  'John Schneider',
#  'Larissa Galagher',
#  'Renée Soutendijk',
#  'Lesley Ann Warren',
#  'Betty White',
#  'Elif Nur Kerkük',
#  'Guillaume de Tonquédec',
#  'Yogendra Tikku',
#  'Joelle Carter',
#  'Kim Min-sang',
#  'Macintyre Dixon',
#  'Norm Macdonald',
#  'Padam Mishra',
#  'Jerry Lewis',
#  'Ashleigh Murray',
#  'Ben Savage',
#  'Raghavendra Kadkol',
#  'Linor Abargil',
#  'James Groom',
#  'Chasty Ballesteros',
#  'Jashanjeet Gosha',
#  'Thelonious Monk',
#  'Atheena Frizzell',
#  'Falz',
#  'Michael Bell',
#  'Lehar Khan',
#  'Craig Ferguson',
#  'Allan Hyde',
#  'Sonja Sohn',
#  'Sanjay Goradia',
#  'Gregory Ojefua',
#  'Jella Haase',
#  'Titikarn Tongprasearth',
#  'Chloe Bayliss',
#  'Alex Brendemühl',
#  'Braeden Lemasters',
#  'Basil Harris',
#  'Olwen Catherine Kelly',
#  'Blair Fowler',
#  'Lexi Perkel',
#  'Francesco Salvi',
#  'Praneet Bhatt',
#  'Connor Williams',
#  'Borja Luna',
#  'Trimala Adhikari',
#  'Bel Powley',
#  'Avika Gor',
#  'Kirby Bliss Blanton',
#  'Anthony Michael Hall',
#  'Barry Pepper',
#  'Brandon Miller',
#  'John Brodsky',
#  'David Meadows',
#  'Edward Hogg',
#  'Brad Savage',
#  'Marton Csokas',
#  'David Kaye',
#  'Kirill Bichutsky',
#  'David Haig',
#  'Nicki Aycox',
#  'Vic Chou',
#  'Johnny Baweja',
#  'Ajay Shankar',
#  'Harsh Vasisht',
#  'Henriette Müller',
#  'Clover Nee',
#  'Pete Postlethwaite',
#  'Sam Skoryna',
#  'Krrish Chhabria',
#  'Giulia Gorietti',
#  'Ajay Naidu',
#  'Anton Yelchin',
#  'José Luis García Pérez',
#  'Julian Sands',
#  'Susan Leong',
#  'Jeannette Sauksteliskis',
#  'Claudio Tolcachir',
#  'Bárbara Lennie',
#  'Mayu Matsuoka',
#  'Jacqueline Kim',
#  'Deep Raj Rana',
#  'Karl Glusman',
#  'Harsh Chhaya',
#  'Grant Campbell',
#  'Theo Rossi',
#  'Katija Pevec',
#  'François Chau',
#  'Vega Tamotia',
#  'Onyeka Onwenu',
#  'Youssef Hajdi',
#  'John Terry',
#  'Carrie Coon',
#  'Agustín Aristarán',
#  'Daniela Rubio',
#  'Harpal Singh',
#  'Anton Gillis-Adelman',
#  'M. Night Shyamalan',
#  'Aarjav Trivedi',
#  'Neena Gupta',
#  'Mickey Gooch Jr.',
#  'Antonio Mourelos',
#  'Clement Metayer',
#  'Anish Trivedi',
#  'Paterson Joseph',
#  'Kevin Kolack',
#  'Celeste Henderson',
#  'Cybill Shepherd',
#  'Stanley Unwin',
#  'Ansiba',
#  'Snoop Dogg',
#  'Subhajit Das',
#  'Nikki Glaser',
#  'Grażyna Staniszewska',
#  'Breanna Yde',
#  'Hülya Gülsen Irmak',
#  'Law Kar-Ying',
#  'Lorenz Martinez',
#  'Mohamed Henedi',
#  'Zainab Balogun',
#  'Jim Norton',
#  'Lauren Cochrane',
#  'Bruce Smith',
#  'Elvira Onetto',
#  'Robert Palfrader',
#  'Warda Rammach',
#  'Bob Odenkirk',
#  'Víctor Trujillo',
#  "Paige O'Hara",
#  'Tanushree Dutta',
#  'Pamu Pamorada',
#  "Michael O'Neill",
#  'Helena Sujecka',
#  'Arya Babbar',
#  'Rubén Rodríguez',
#  'Sabrina Rochelle Kalangie',
#  'Kevin B. McGlynn',
#  'Vidyadhar Joshi',
#  'Michael Lerner',
#  'Megan Park',
#  'Nick Rhys',
#  'Shen Chan',
#  'Joseph Chang',
#  'Glen Powell',
#  'Thaila Ayala',
#  'Bautista Lena',
#  'David Lee',
#  'John C. Reilly',
#  'Zarina Wahab',
#  'Khalil Ramos',
#  'Derek Ramsay',
#  'Travis Hammer',
#  'Naveen Kasturia',
#  'Sotida Arpon',
#  'Ashwath Bhatt',
#  'Tony Shalhoub',
#  'Rachel Vanduzer',
#  'Sally Kirkland',
#  'Mariama Gassama',
#  'Sara Casasnovas',
#  'Jessica Meraz',
#  'Ariadna Cabrol',
#  'Ella Anderson',
#  'Siddharth Menon',
#  'Indrani Haldar',
#  'Shantilal Mukherjee',
#  'Kate Fahy',
#  'Serge Houde',
#  'James Vincent Meredith',
#  'Manish Khanna',
#  'Kevyn Aucoin',
#  'Shaun Gerardo',
#  'Diaa El Merghany',
#  'Mehul Buch',
#  'Prachi Shah',
#  'Matt Doran',
#  'Rosamund Marks',
#  'Rico Paris',
#  'Agustín Silva',
#  'Shawn Wayans',
#  'Zena Grey',
#  'Rupa Tamang',
#  'Malak Koura',
#  'Hung Wei',
#  'Mahesh Gupta',
#  'Harry DeLeyer',
#  'Javier Delgiudice',
#  'Kapil Punjabi',
#  'Amir Bageria',
#  'Corbin Timbrook',
#  'Blanca Portillo',
#  'Samina Ahmad',
#  'Pierre Salvadori',
#  'Erica Durance',
#  'Kristin Booth',
#  'Cody Fern',
#  'Carrie Lazar',
#  'Gambit Saifullah',
#  'Ajay Raj',
#  'Taylor James',
#  'Sage Stallone',
#  'Zazie Beetz',
#  'Thomas Cocquerel',
#  'Jamie Choi',
#  'Dustin Milligan',
#  'Shinji Uchiyama',
#  'Jyoti Pawar',
#  'Pakoda Pandi',
#  'Cynthia Kirchner',
#  'Olivier Claverie',
#  'Kacie Anderson',
#  'Nora El Koussour',
#  'Aurélien Cotentin',
#  'Flonja Kodheli',
#  'Billy West',
#  'Clarissa Müller',
#  'Rebecca Santhosh',
#  'Michelle Arthur',
#  'Alice Ziolkoski',
#  'Hamza Abbasi',
#  'Mittal Chouhan',
#  'Iniya',
#  'Phoomjai Tangsanga',
#  'Doon Mackichan',
#  'Patrick Hivon',
#  'Katie Blake',
#  'Sanya Malhotra',
#  'Zaskia Adya Mecca',
#  'Tomiwa Edun',
#  'Dustin Ingram',
#  'Shivani Joshi',
#  'Jessika Van',
#  'Haley Bennett',
#  'Tom Basden',
#  'Alejandra Flechner',
#  'Dan Renton Skinner',
#  'Raman Trikha',
#  'Tammy Gillis',
#  'Engin Günaydın',
#  'Lau Ho-Chi',
#  'John Apicella',
#  'Derek Luke',
#  'Ian McElhinney',
#  'Mehmet Selim Akgül',
#  'Tim Hopper',
#  'Paul Giamatti',
#  'Gia Re',
#  'Chelsea Islan',
#  'Steve Greene',
#  'Neetu Chandra',
#  'José Ángel Egido',
#  'Chung Wang',
#  'Patrick Bauchau',
#  'Salma Ashai',
#  'Janet McTeer',
#  'Faiza Mahnur',
#  'Swati Semwal',
#  'Freddy Rodríguez',
#  'Nuria Prims',
#  'Jean-Benoît Ugeux',
#  'Jenica Bergere',
#  'William Calvert',
#  'Simon Kunz',
#  'Kalaiyarasan',
#  'Kanchan Mullick',
#  'Shah Rukh Khan',
#  'Ege Kökenli',
#  'Yamila Saud',
#  'Henry O',
#  'Alex Frnka',
#  'Preity Zinta',
#  'John Wright Jr.',
#  'Enid Graham',
#  'Claudine Sosa',
#  'Danielle Panabaker',
#  'Annabelle Dexter-Jones',
#  'Leslie Cheung',
#  'Aashish Chaudhary',
#  'Kenneth Tigar',
#  'Cate Blanchett',
#  'Marcus Thomas',
#  'Angus Macfadyen',
#  'Kelly Lynch',
#  'Lavell Crawford',
#  'Octavio Michel',
#  'Richard Grieco',
#  'Henry Cavill',
#  'Kenji Hamada',
#  'Kathy Bates',
#  'Eréndira Ibarra',
#  'Gonzalo VIzán',
#  'Charlie Cho',
#  'Kelvin Harrison Jr.',
#  'Guillaume Canet',
#  'Christopher Plummer',
#  'Jonathan Hyde',
#  'Marc Jarousseau',
#  'Cathy Cavadini',
#  'Tom Wright',
#  'Stuti Dwivedi',
#  'Maya Franzoi',
#  'Gudrun Sesselja Arnardottir',
#  'David Shannon',
#  'Robb Wells',
#  'Sabeeka Imam',
#  'Steve Tientcheu',
#  'Bratya Basu',
#  'Lourinelson Vladmir',
#  'Lisa Vidal',
#  'Damian Lau',
#  'Walter Huston',
#  'Roxy Nel',
#  'Joseph Fiennes',
#  'Donald Faison',
#  'Unsho Ishizuka',
#  'Colin Woodell',
#  'Robert Mitchell',
#  'Jeremy Blackman',
#  'Anjelika Washington',
#  'Regina Torné',
#  'D P Ghani',
#  'Consuelo Vega',
#  'Andy Liang',
#  'Giancarlo Giannini',
#  'Nina Siemaszko',
#  'Gao Yuanyuan',
#  'Nirmal Rishi',
#  'Teruaki Ogawa',
#  'Hal Smith',
#  'Brian Caspe',
#  'Alexandra Daddario',
#  'Tanuja',
#  'Lyndon Smith',
#  'Arturo Ríos',
#  'Tom Aldredge',
#  'Grégoire Isvarine',
#  'Majed Abdulazim',
#  'Rachel Harrison',
#  'Cameron Harlow',
#  'Elizabeth Irving',
#  'Benjamin Gilani',
#  'Chelcie Ross',
#  'Alejandro Vera',
#  'Teun Peters',
#  'Castille Landon',
#  'Marcus Chong',
#  'Enspirit',
#  'Fábio Lago',
#  'Lee Tockar',
#  'Victor J. Ho',
#  'Christian Bale',
#  'Martyn Ford',
#  'Eric Stonestreet',
#  'Sharlto Copley',
#  'Anika Noni Rose',
#  'Danny Huston',
#  'Antonio Alvarez',
#  'Man-Wai Wong',
#  'Jonathan Park',
#  'Deep Joshi',
#  'Anne-Marie Duff',
#  'Gloria Allred',
#  'Helene Joy',
#  'Ronnie Coleman',
#  'Maria Kawamura',
#  'Tarık Papuççuoğlu',
#  'Reese Alexander',
#  'Amy Sedaris',
#  'Kevin Bishop',
#  'Kaizaad Kotwal',
#  'Saara Chaudry',
#  'Scott Mescudi',
#  'Patricio Contreras',
#  'Mugihito',
#  'Kurt Max Runte',
#  'David Yow',
#  'Abigail Pniowsky',
#  'David Koechner',
#  'Dewi Irawan',
#  'Kitty Speed',
#  'Paula Carruega',
#  'Joel David Moore',
#  'Kiefer Sutherland',
#  'David Lewis',
#  'Jorge Sesán',
#  'Wayne Hope',
#  'Stephen Erza  Hughes',
#  'Kitu Gidwani',
#  'Pia Lanciotti',
#  'Maggie Gyllenhaal',
#  'Trent Haaga',
#  'Subhash Ghai',
#  'Milhem Cortaz',
#  'Mathew St. Patrick',
#  'Ashok Samarth',
#  'Sylvia Hoeks',
#  'Vijay Pande',
#  'Osas Ighodaro Ajibade',
#  'Mary Jane Wells',
#  'Jennifer Beals',
#  'Józef Nowak',
#  'Shubham Chintamani',
#  'Mercedes Morán',
#  'Luke Spencer Roberts',
#  'Rhosinah Sekeleti',
#  'Gwen Zamora',
#  'Jayma Mays',
#  'Sarah Grey',
#  'Théo Fernandez',
#  'Halima Karaouane',
#  'Indrasish Roy',
#  'Sharvari Jamenis',
#  'Alan Arkin',
#  'J.D. Ryznar',
#  'Zoltán Fenyvesi',
#  'Nestor Aaron Absera',
#  'Kevin Sizemore',
#  'Sean "P. Diddy" Combs',
#  'Sofinar',
#  'Mather Zickel',
#  'Mark Sheppard',
#  'Kaycee Moore',
#  'Sophie Skelton',
#  'Mel Giedroyc',
#  'Yuka Iguchi',
#  'Danielle von Zerneck',
#  'D.L. Hughley',
#  'Julie Walters',
#  'Robert Gustafsson',
#  'Melanie Stone',
#  'Nicollette Sheridan',
#  'Stockard Channing',
#  'Nancy Travis',
#  'McKayla Witt',
#  'Oliver Hudson',
#  'Reagan Yates',
#  'Mohamed Alkendi',
#  'Rajat Kaul',
#  'Joel Dawson',
#  'Shashank Purushotham',
#  'Christopher Connelly',
#  'Michelle Lehane',
#  'Zina Bethune',
#  'Varun Mehra',
#  'Daniel Sharman',
#  'Aleksander Bardini',
#  'Mario Adorf',
#  'Sedef Avcı',
#  'Maïwenn Le Besco',
#  'Lara Flynn Boyle',
#  'Jonathan Keltz',
#  'Alan Bates',
#  'Camille Guaty',
#  'Joey King',
#  'Paula Pell',
#  'Sonu Sood',
#  'Sergio Ruggeri',
#  'David Hyde Pierce',
#  'Zion Clark',
#  'Nguyen Ngan Ha',
#  'Jae-eung Lee',
#  'Faris Khalid',
#  'Praveen Tarde',
#  'Bobby Naderi',
#  'Rosie Fellner',
#  'Rakchawan Maroukasonti',
#  'Chang-wook Ji',
#  'Georgie Flores',
#  'Becky Ann Baker',
#  'Atul Kulkarni',
#  'S. Epatha Merkerson',
#  'Keiko Nemoto',
#  'Ebon Moss-Bachrach',
#  'Michael Caton',
#  'Tian Yu',
#  'Chapman To',
#  'Sophie Thompson',
#  'Greg Proops',
#  'Arwa Gouda',
#  'Sarina Farhadi',
#  'Sam Horrigan',
#  'Margherita Donato',
#  'Sethu Lakshmi',
#  'Alec Baldwin',
#  'Lorene Ren',
#  'Eugenia Suárez',
#  'Andrew Shaver',
#  'Tirso Cruz III',
#  'Kevin Hart',
#  'Julie Depardieu',
#  'Alan Powell',
#  'Yoo Yeon-seok',
#  'Gijs Scholten van Aschat',
#  'Dan Payne',
#  'Roman Atwood',
#  'Vicente Romero',
#  'Diana Raval',
#  'Mayur Puri',
#  'Suna Yıldızoğlu',
#  'Françoise Yip',
#  'Husam Chadat',
#  'Kevin Kline',
#  'AFRA',
#  'Ikranagara',
#  'Gabriela Freire',
#  'Jane Singer',
#  'Omar Gooding',
#  'Ronni Ancona',
#  'Michał Bajor',
#  'Nick Damici',
#  'Tabu',
#  'Roger Cross',
#  'Serkan Keskin',
#  'Buddy Vedder',
#  'Kevin Costner',
#  'Tsuyoshi Muro',
#  'Tiaré Scanda',
#  'Toshiro Hisaki',
#  'Mukesh Tiwari',
#  'Jerry Orbach',
#  'Harrison Gilbertson',
#  'Roshan Mathew',
#  'Geng Bowen',
#  'Marcello Thedford',
#  'Nivin Madi',
#  'Ron Rifkin',
#  'Keira Knightley',
#  'Zhao Jian',
#  'Gulzar Chahal',
#  'Avraham Aviv Alush',
#  'Doug Cox',
#  'Gabriel Braga Nunes',
#  'Philip Goodwin',
#  'Tom Everett',
#  'Jakub Gierszal',
#  'Athiya Shetty',
#  'Yeni Alvarez',
#  'Gary Grubbs',
#  'Britt Robertson',
#  'Subhrajyoti Barat',
#  'Pankaj Jha',
#  'John Early',
#  'Kongsak Kaenmeepol',
#  'Anton Lesser',
#  'Tammy Townsend',
#  'Déborah Révy',
#  'Brian White',
#  'Kim Hawthorne',
#  'James Maslow',
#  'Andrew Neethling',
#  'Richard Jenkins',
#  'Mike Seal',
#  'Ken Marino',
#  'Leo Hatton',
#  'Raye Birk',
#  'Nadji Jeter',
#  'Dong Jie',
#  'Elisa Pinheiro',
#  'Terele Pávez',
#  'Jing Wu',
#  'Suzanne Krull',
#  'Leemore Marrett Jr.',
#  'Carissa Putri',
#  'Mark van Eeuwen',
#  'Wendi McLendon-Covey',
#  'Puttachat Pongsuchat',
#  'Carol Cleveland',
#  'Ian Buchanan',
#  'Britt McKillip',
#  'Tsai Chen-nan',
#  'Zohra Sehgal',
#  'Carel Struycken',
#  'Milind Shirole',
#  'Tyler Patrick Jones',
#  'Jason Grasl',
#  'Scott Jurek',
#  'Josh Epstein',
#  'Francis Collins',
#  'Garrick Hagon',
#  'Poon Chan-leung',
#  'Mike Hanford',
#  'Ikumi Nakagami',
#  'Chad Connell',
#  'Howard Hesseman',
#  'Liviu Pintileasa',
#  'Alain Prost',
#  'Lucie Aron',
#  'Chethan Dsouza',
#  'Anita Date',
#  'Cloris Leachman',
#  'Ayesha',
#  'Stephanie Schildknecht',
#  'Talia Balsam',
#  'Virginia Rodriguez',
#  'Binnu Dhillon',
#  'Henri Garcin',
#  'Don Warrington',
#  'Sean Patrick Flanery',
#  'Audrey Wasilewski',
#  'Mark Caso',
#  'Sol Gaschetto',
#  'Shelley Thompson',
#  'Vasu Vikram',
#  'Isiah Lea',
#  'Parakh Madan',
#  'Eduardo Negrete',
#  'Alice Englert',
#  'Tyler Labine',
#  'Nacho Fresneda',
#  'Gregorio Duvivier',
#  'Amr Youssef',
#  'Andy Lau',
#  'Peter Michael Goetz',
#  'Kainaat Arora',
#  'Ashwin Chitale',
#  'Thomas Stipsits',
#  'Aya Cash',
#  'Sung-woong Park',
#  'Tim Ahern',
#  ...}

# %%
categories = list(data_reduit["listed_in"].values)
categories_set = set()


for i in range(len(categories)):
    liste = categories[i]
    dir_ = liste.split(", ")
    for y in dir_:
        categories_set.add(y)

categories_set
# Out:
# {'Action & Adventure',
#  'Anime Features',
#  'Anime Series',
#  'British TV Shows',
#  'Children & Family Movies',
#  'Classic & Cult TV',
#  'Classic Movies',
#  'Comedies',
#  'Crime TV Shows',
#  'Cult Movies',
#  'Documentaries',
#  'Docuseries',
#  'Dramas',
#  'Faith & Spirituality',
#  'Horror Movies',
#  'Independent Movies',
#  'International Movies',
#  'International TV Shows',
#  "Kids' TV",
#  'Korean TV Shows',
#  'LGBTQ Movies',
#  'Movies',
#  'Music & Musicals',
#  'Reality TV',
#  'Romantic Movies',
#  'Romantic TV Shows',
#  'Sci-Fi & Fantasy',
#  'Science & Nature TV',
#  'Spanish-Language TV Shows',
#  'Sports Movies',
#  'Stand-Up Comedy',
#  'Stand-Up Comedy & Talk Shows',
#  'TV Action & Adventure',
#  'TV Comedies',
#  'TV Dramas',
#  'TV Horror',
#  'TV Mysteries',
#  'TV Sci-Fi & Fantasy',
#  'TV Shows',
#  'TV Thrillers',
#  'Teen TV Shows',
#  'Thrillers'}

# %%
INSERT INTO `director` (`director_name`) SELECT DISTINCT `COL 5` FROM `table 10`
INSERT INTO `actor` (`actor_name`) SELECT DISTINCT `COL 6` FROM `table 10`
INSERT INTO `listed_in` (`liste_name`) SELECT DISTINCT `COL 12` FROM `table 10`

# %%
# procédure pour récupérer le nom d'un film en fonction de la liste des acteurs
DELIMITER |
CREATE PROCEDURE films_actor_all (IN actor_studio VARCHAR(256))
BEGIN
SELECT title FROM film
INNER JOIN actor_film ON film.show_id = actor_film.id_film
INNER JOIN actor ON actor_film.id_actor = actor.id_actor WHERE actor_name = actor_studio;
END |
DELIMITER ;

CALL films_actor_all()

# %%
#procédure pour récupérer le nom d'un film en fonction du ou des producteurs
DELIMITER |
CREATE PROCEDURE films_director_all (IN actor_studio VARCHAR(256))
BEGIN
SELECT title FROM film
INNER JOIN director_film ON film.show_id = director_film.id_film
INNER JOIN director ON director_film.id_director = director.id_director WHERE director_name = actor_studio;
END |
DELIMITER ;

# %%
#procédure pour récupérer le nom d'un film en fonction de sa catégorie
DELIMITER |
CREATE PROCEDURE gived_listed_in (IN actor_studio VARCHAR(256))
BEGIN
SELECT title FROM film
INNER JOIN dlisted_in_film ON film.show_id = listed_in_film.id_film
INNER JOIN listed_in ON listed_in_film.id_liste = listed_in.id_liste WHERE liste_name = actor_studio;
END |
DELIMITER ;
# Out:
#   File "<ipython-input-36-8fc5276046e5>", line 2
#     DELIMITER |
#                ^
# SyntaxError: invalid syntax

# %%
#procédure pour récupérer le nom d'un film en fonction de son pays

DELIMITER |
CREATE PROCEDURE all_film_country (IN give_country VARCHAR(256))
BEGIN
SELECT title FROM film
INNER JOIN country_film ON film.show_id = country_film.id_country
INNER JOIN country ON country_film.id_country = country.id_country WHERE country_name = give_country;
END |
DELIMITER ;
# Out:
#   File "<ipython-input-37-1ecf23e85f4b>", line 3
#     DELIMITER |
#                ^
# SyntaxError: invalid syntax

# %%
DELIMITER |
CREATE PROCEDURE film_date
(IN annee INT)
BEGIN
SELECT * FROM avions WHERE release_year < annee;
END|
DELIMITER ;
CALL film_date(2000);

CREATE VIEW  all_actor_film AS select actor.actor_name  AS
select actor_name FROM actor 
JOIN actor, film_actor ON actor.id_actor = film_actor.id_actor  
JOIN film, film_actor ON film.show_id = film_actor.show_id;
# Out:
#   File "<ipython-input-38-643aa02b224e>", line 1
#     DELIMITER |
#                ^
# SyntaxError: invalid syntax

# %%
#vue qui récupère la liste des films, et dnne des informations proveant des autres tables
CREATE VIEW all_film AS SELECT title, director_name, actor_name, country_name, liste_name, release_year, rating, duration, description FROM film
NATURAL JOIN actor
NATURAL JOIN country
NATURAL JOIN director
NATURAL JOIN listed_in
